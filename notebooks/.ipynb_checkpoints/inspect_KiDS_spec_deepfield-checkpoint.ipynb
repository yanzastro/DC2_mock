# %%
import os
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# KV450_path = os.path.expanduser('~')+'/DATA/KV450/SPECZ/DIR_zCOSMOS.fits'
# KV450_file = fits.open(KV450_path, mode="update")
# KV450_file[1].columns

# %%
MICE2_path = os.path.expanduser('~')+'/DATA/KV450/SPECZ/SDSS_masked.fits'
MICE2_file = fits.open(MICE2_path)

# %%
MICE2_file[1].data['ID'].size
# Out:
# 5966

# %%
outroot = os.path.expanduser('~')+'/DATA/MICE2_KV450_cut/REALISATIONS_magnification_on'

surveys = ['DEEP2', 'VVDSf02', 'zCOSMOS']
zspec_mock = np.array([])
zb_mock = np.array([])
mag_mock = np.array([])
for survey in surveys:
    KV450_path = outroot+'/'+survey+'_phot_samples/'+survey+'_phot_samples_1.fits'
    KV450_file = fits.open(KV450_path, mode="update")
    zspec_mock = np.hstack([zspec_mock, KV450_file[1].data['z_cgal_v']])
    zb_mock = np.hstack([zb_mock, KV450_file[1].data['Z_B']])
    mag_mock= np.hstack([mag_mock, KV450_file[1].data['sdss_r_obs_mag']])

# %%
surveys = ['DEEP2', 'VVDSf02', 'zCOSMOS']
zspec = np.array([])
zb = np.array([])
mag = np.array([])
for survey in surveys:
    KV450_path = os.path.expanduser('~')+'/DATA/KV450/SPECZ/DIR_'+survey+'.fits'
    KV450_file = fits.open(KV450_path, mode="update")
    zspec = np.hstack([zspec, (KV450_file[1].data['z_spec_A'] + KV450_file[1].data['z_spec_B'] + KV450_file[1].data['z_spec_C'])/3])
    zb = np.hstack([zb, KV450_file[1].data['Z_B']])
    mag = np.hstack([mag, KV450_file[1].data['MAG_GAAP_r']])
#randind = np.random.randint(0, zb.size, 10000)
#KV450_file[1].data = KV450_file[1].data[randind]
#KV450_file.writeto(os.path.expanduser('~')+'/DATA/KV450/KiDS_VIKING/KV450_north_cut.cat', overwrite=True)

# %%
def hist_plot(data, bins, color, ax, fmt=''):
    ax.hist(data, bins, color=color, alpha=0.5, density=True)
    ax.hist(data, bins, color=color, histtype='step', density=True)
    return

def stat_plot(bindata, stat, bins, color, ax, label='', fmt='-'):
    stat_sum, edges = np.histogram(bindata, bins=bins, weights=stat)
    norm, edges = np.histogram(bindata, bins=bins)
    bincenter = (edges[1:]+edges[:-1])/2
    stat_mean = stat_sum/norm
    #print(stat_mean)
    ax.plot(bincenter, stat_mean, color=color, label=label, linestyle=fmt)
    return

def mad_plot(bindata, dz, bins, color, ax, label='', fmt='-'):
    znorms, edges = np.histogram(bindata, bins=bins)
    dzs, edges = np.histogram(bindata, bins=bins, weights=dz) 
    bincenter = (edges[1:]+edges[:-1])/2
    mad = np.zeros(edges.size-1)
    for i in range(len(edges) - 1):
        bin_mask = (
            (bindata >= edges[i]) &
            (bindata < edges[i + 1]))
        mad[i] = 1.4826 * np.median(
            np.abs(dz[bin_mask] - (dzs/znorms)[i]))
    ax.plot(bincenter, mad, color=color, label=label, linestyle=fmt)
    return

def plot_BPZ_stats(z_spec, z_phot, mag, axes, color='C1', fmt='-', label='', 
                   zb_label='Z_B', zspec_label='z_spec', 
                   zphot_label='z_phot', mag_label='mag_r', survey_label='KV450', 
                   zbin = np.arange(0.05, 1.5+0.05, 0.05),
                   magbin = np.arange(20, 25, .1)):
    dz = (z_phot-z_spec)/(1+z_spec)
    dz015 = (np.abs(dz) > 0.15)

    
    hist_plot(z_spec[z_spec<1.5],  zbin, color=color, ax=axes[3][0], fmt=fmt)
    hist_plot(z_phot[z_phot<1.5], zbin, color=color, ax=axes[3][1], fmt=fmt)
    hist_plot(mag[mag<26], magbin, color=color, ax=axes[3][2], fmt=fmt)
    axes[3][0].set_ylabel('PDF', fontsize=14)
    axes[3][0].set_xlabel(zspec_label, fontsize=14)
    axes[3][1].set_xlabel(zphot_label, fontsize=14)
    axes[3][2].set_xlabel(mag_label)

    mad_plot(z_spec, dz, zbin, color, axes[0][0], label=survey_label, fmt=fmt)
    mad_plot(z_phot, dz, zbin, color, axes[0][1], fmt=fmt)
    mad_plot(mag, dz, magbin, color, axes[0][2], fmt=fmt)
    axes[0][0].set_ylabel(r'$\sigma_{\mathrm{m}}$', fontsize=14)

    stat_plot(z_spec, dz, zbin, color, axes[1][0], fmt=fmt)
    stat_plot(z_phot, dz, zbin, color, axes[1][1], fmt=fmt)
    stat_plot(mag, dz, magbin, color, axes[1][2], fmt=fmt)
    axes[1][0].set_ylabel(r'$\mu_{\delta z}$', fontsize=14)

    stat_plot(z_spec, dz015*1.0, zbin, color, axes[2][0], fmt=fmt)
    stat_plot(z_phot, dz015*1.0, zbin, color, axes[2][1], fmt=fmt)
    stat_plot(mag, dz015*1.0, magbin, color, axes[2][2], fmt=fmt)
    axes[2][0].set_ylabel(r'$\zeta_{0.15}$', fontsize=14)
    
    return

# %%
fig, axes = plt.subplots(4,3, figsize=(20, 20))
plot_BPZ_stats(zspec, zb, mag, axes, color='C3', survey_label='KV450')
plot_BPZ_stats(zspec_mock, zb_mock, mag_mock, axes, color='C0', survey_label='MICE2 mock')
axes[0][0].legend(fontsize=14)

for i in range(4):
    for j in range(3):
        axes[i][j].tick_params("both", direction="in",
                bottom=True, top=True, left=True, right=True)
        axes[i][j].sharey(axes[i][0])
        axes[i][j].sharex(axes[0][j])

plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
outroot = os.path.expanduser('~')+'/DATA/MICE2_KV450_cut/REALISATIONS_magnification_on'

KV450_full_file = fits.open(os.path.expanduser('~')+'/DATA/KV450/KiDS_VIKING/KV450_north.cat')

fig, axes = plt.subplots(4,3, figsize=(20, 20))


surveys = ['DEEP2', 'VVDSf02', 'zCOSMOS']
zspec_deep = np.array([])
zb_deep = np.array([])
mag_deep = np.array([])
for survey in surveys:
    KV450_path = outroot+'/'+survey+'_phot_samples/'+survey+'_phot_samples_1.fits'
    KV450_file = fits.open(KV450_path, mode="update")
    zspec_deep = np.hstack([zspec_deep, KV450_file[1].data['z_cgal_v']])
    zb_deep = np.hstack([zb_deep, KV450_file[1].data['Z_B']])
    mag_deep= np.hstack([mag_deep, KV450_file[1].data['sdss_r_obs_mag']])
plot_BPZ_stats(zspec_deep, zb_deep, mag_deep, axes, color='C0', survey_label='MICE2 mock, deep')

surveys = ['SDSS_BOSS', 'WiggleZ', 'GAMA']

colors = {'SDSS_BOSS':"C3",
         'WiggleZ':"C4",
         'GAMA':"C5",}

zspec_mock = np.array([])
zb_mock = np.array([])
mag_mock = np.array([])

magbins = {'SDSS_BOSS': np.arange(20, 22, .1),
          'WiggleZ': np.arange(20, 22, .1),
          'GAMA': np.arange(19, 20, .05),}

zbins = {'SDSS_BOSS': np.arange(0.05, 1.2+0.05, 0.05),
          'WiggleZ': np.arange(0.05, 1.2+0.05, 0.05),
          'GAMA': np.arange(0.05, 0.8+0.05, 0.05),}



for survey in surveys:
    mock_path = outroot+'/'+survey+'_phot_samples/'+survey+'_phot_samples_0.fits'
    mock_file = fits.open(mock_path, mode="update")
    zspec_mock = mock_file[1].data['z_cgal_v']
    zb_mock = mock_file[1].data['Z_B']
    mag_mock= mock_file[1].data['sdss_r_obs_mag']

    plot_BPZ_stats(zspec_mock, zb_mock, mag_mock, axes, color=colors[survey], survey_label='MICE2 mock, '+survey, 
                   zbin = zbins[survey],
                       magbin = magbins[survey])
    
    #KV450_path = os.path.expanduser('~')+'/DATA/KV450/SPECZ/'+survey+'_masked.fits'
    #KV450_file = fits.open(KV450_path, mode="update")
    #zspec = KV450_file[1].data['z_spec']
    #ind = KV450_file[1].data['ID']
    #zb = KV450_full_file[1].data['Z_B'][ind]
    #mag = KV450_full_file[1].data['MAG_GAAP_r'][ind]
    
    #plot_BPZ_stats(zspec, zb, mag, axes, color=colors[survey], survey_label='MICE2 mock, '+survey, 
    #               zbin = zbins[survey],
    #                   magbin = magbins[survey], fmt='--')

axes[0][0].legend(fontsize=14)

for i in range(4):
    for j in range(3):
        axes[i][j].tick_params("both", direction="in",
                bottom=True, top=True, left=True, right=True)
        axes[i][j].sharey(axes[i][0])
        axes[i][j].sharex(axes[0][j])

plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
outroot = os.path.expanduser('~')+'/DATA/cosmoDC2/REALISATIONS/'

fig, axes = plt.subplots(4,3, figsize=(20, 20))

surveys = ['SDSS_BOSS', 'WiggleZ', 'GAMA']

colors = {'SDSS_BOSS':"C3",
         'WiggleZ':"C4",
         'GAMA':"C5",}

zspec_mock = np.array([])
zb_mock = np.array([])
mag_mock = np.array([])

magbins = {'SDSS_BOSS': np.arange(20, 23, .1),
          'WiggleZ': np.arange(20, 23, .1),
          'GAMA': np.arange(19, 20, .05),}

zbins = {'SDSS_BOSS': np.arange(0.4, 1.0+0.05, 0.05),
          'WiggleZ': np.arange(0.05, 1.2+0.05, 0.05),
          'GAMA': np.arange(0.05, 0.8+0.05, 0.05),}



for survey in surveys:
    mock_path = outroot+'/'+survey+'_phot_samples/'+survey+'_phot_samples_0.fits'
    mock_file = fits.open(mock_path, mode="update")
    zspec_mock = mock_file[1].data['redshift']
    zb_mock = mock_file[1].data['Z_B']
    print(zb_mock.size)
    mag_mock= mock_file[1].data['mag_r_lsst_obs']

    plot_BPZ_stats(zspec_mock, zb_mock, mag_mock, axes, color=colors[survey], survey_label='DC2 mock, '+survey, 
                   zbin = zbins[survey],
                       magbin = magbins[survey])
    
    #plot_BPZ_stats(zspec, zb, mag, axes, color=colors[survey], survey_label='MICE2 mock, '+survey, 
    #               zbin = zbins[survey],
    #                   magbin = magbins[survey], fmt='--')

axes[0][0].legend(fontsize=14)

for i in range(4):
    for j in range(3):
        axes[i][j].tick_params("both", direction="in",
                bottom=True, top=True, left=True, right=True)
        axes[i][j].sharey(axes[i][0])
        axes[i][j].sharex(axes[0][j])

plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# 3516
# 15704
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
outroot = os.path.expanduser('~')+'/DATA/MICE2_KV450_cut/REALISATIONS_magnification_on'

surveys = ['WiggleZ']
zspec_mock = np.array([])
zb_mock = np.array([])
mag_mock = np.array([])
for survey in surveys:
    KV450_path = outroot+'/'+survey+'_phot_samples/'+survey+'_phot_samples_0.fits'
    KV450_file = fits.open(KV450_path, mode="update")
    zspec_mock = np.hstack([zspec_mock, KV450_file[1].data['z_cgal_v']])
    zb_mock = np.hstack([zb_mock, KV450_file[1].data['Z_B']])
    mag_mock= np.hstack([mag_mock, KV450_file[1].data['sdss_r_obs_mag']])


fig, axes = plt.subplots(4,3, figsize=(20, 20))
#plot_BPZ_stats(zspec, zb, mag, axes, color='C3', survey_label='KV450')
plot_BPZ_stats(zspec_mock, zb_mock, mag_mock, axes, color='C0', survey_label='MICE2 mock, '+surveys[0], zbin = np.arange(0.05, 1.2+0.05, 0.05),
                   magbin = np.arange(20, 22, .1))
axes[0][0].legend(fontsize=14)

for i in range(4):
    for j in range(3):
        axes[i][j].tick_params("both", direction="in",
                bottom=True, top=True, left=True, right=True)
        axes[i][j].sharey(axes[i][0])
        axes[i][j].sharex(axes[0][j])

plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.

# %%
mag_mock
# Out:
# array([19.53102303, 19.75699615, 19.72694397, ..., 19.71939468,
#        19.74998474, 19.73154831])

# %%
outroot = os.path.expanduser('~')+'/DATA/MICE2_KV450_cut/REALISATIONS_magnification_on'

surveys = ['GAMA']
zspec_mock = np.array([])
zb_mock = np.array([])
mag_mock = np.array([])
for survey in surveys:
    KV450_path = outroot+'/'+survey+'_phot_samples/'+survey+'_phot_samples_0.fits'
    KV450_file = fits.open(KV450_path, mode="update")
    zspec_mock = np.hstack([zspec_mock, KV450_file[1].data['z_cgal_v']])
    zb_mock = np.hstack([zb_mock, KV450_file[1].data['Z_B']])
    mag_mock= np.hstack([mag_mock, KV450_file[1].data['sdss_r_obs_mag']])


fig, axes = plt.subplots(4,3, figsize=(20, 20))
#plot_BPZ_stats(zspec, zb, mag, axes, color='C3', survey_label='KV450')
plot_BPZ_stats(zspec_mock, zb_mock, mag_mock, axes, color='C0', survey_label='MICE2 mock, '+surveys[0], zbin = np.arange(0.05, 0.8+0.05, 0.05),
                   magbin = 15)
axes[0][0].legend(fontsize=14)

for i in range(4):
    for j in range(3):
        axes[i][j].tick_params("both", direction="in",
                bottom=True, top=True, left=True, right=True)
        axes[i][j].sharey(axes[i][0])
        axes[i][j].sharex(axes[0][j])

plt.subplots_adjust(wspace=0, hspace=0)
